# %%
import librosa
import IPython.display as ipd
import matplotlib.pyplot as plt
import librosa.display

# %%
x , sr = librosa.load('./violence.mp3')

# %%
print(type(x), type(sr))
# Out:
# <class 'numpy.ndarray'> <class 'int'>

# %%
audio_data='./violence.mp3'

# %%
ipd.Audio(audio_data)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.figure(figsize=(14, 5))
librosa.display.waveshow(x, sr=sr)

# %%
X = librosa.stft(x)
Xdb = librosa.amplitude_to_db(abs(X))
plt.figure(figsize=(14, 5))
librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz')
plt.colorbar()

# %%
librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='log')
plt.colorbar()

# %%
mfccs = librosa.feature.mfcc(y=x, sr=sr)
print(mfccs.shape)
plt.figure(figsize=(15, 7))
librosa.display.specshow(mfccs, sr=sr, x_axis='time')
# Out:
# (20, 1996)

# %%
audio_datas= [('./s1.mp3','Female Screem'),('./s2.wav','Male Screem'),('./c1.mp3','Distance Chatting'),('./c2.wav','Noisy Chatting'),('./violence.mp3','Violent Scene')]

# %%
fig, ax = plt.subplots(nrows=5, sharex=True)
i=0
for item, label in audio_datas:
    x , sr = librosa.load(item)
    librosa.display.waveshow(x, sr=sr, ax=ax[i], label=label)
#     ax[i].set(title='Multiple waveforms')
    ax[i].legend()
    i=i+1
#     mfccs = librosa.feature.mfcc(y=x, sr=sr)
#     print(mfccs.shape)
#     plt.figure(figsize=(15, 7))
#     librosa.display.specshow(mfccs, sr=sr, x_axis='time')

# %%
pip install textwrap3
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
# from textwrap3 import wrap
fig, ax = plt.subplots(1, 5, figsize=(20, 3))
i=0
for item, label in audio_datas:
    x , sr = librosa.load(item)
#     librosa.display.waveshow(x, sr=sr, ax=ax[i], label=label)
#     ax[i].set(title='Multiple waveforms')
#     ax[i].legend()
    
    mfccs = librosa.feature.mfcc(y=x, sr=sr)
#     print(mfccs.shape)
    
    librosa.display.specshow(mfccs, sr=sr, ax=ax[i], x_axis='time')
#     ax[i].set_title("\n".join(wrap(label, 10)))
    ax[i].set_title(label)
    i=i+1

# %%
x , sr = librosa.load(item)
mfccs = librosa.feature.mfcc(y=x, sr=sr)
plt.figure(figsize=(5, 3))
librosa.display.specshow(mfccs, sr=sr, x_axis='time')
